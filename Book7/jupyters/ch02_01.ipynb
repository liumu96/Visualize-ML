# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/09/82/5a5eee685095a6c1f8968db75bba8536baa8046c970be25e1ac91a843839/yfinance-0.2.33-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.33-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/b6/2c/e391d6d57bbd837d383a6b69b54ecb4768d75b31d8bc7a380b4b4afe4cb2/frozendict-2.3.10-py3-none-any.whl.metadata
#   Downloading frozendict-2.3.10-py3-none-any.whl.metadata (20 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.17.0-cp311-cp311-macosx_11_0_arm64.whl
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 362.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: soupsieve>1.2 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/liuxing/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Downloading yfinance-0.2.33-py2.py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 1.1 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Downloading frozendict-2.3.10-py3-none-any.whl (14 kB)
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.3.10 html5lib-1.1 multitasking-0.0.11 peewee-3.17.0 yfinance-0.2.33

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
import scipy.stats as stats
import statsmodels.api as sm

# %%
p = plt.rcParams
# p["font.sans-serif"] = ["Roboto"]
p["font.weight"] = "light"
p["ytick.minor.visible"] = False
p["xtick.minor.visible"] = False
p["axes.grid"] = True
p["grid.color"] = "0.5"
p["grid.linewidth"] = 0.5

# %%
y_x_df_raw = yf.download(['AAPL', '^GSPC'], start="2020-01-01", end="2020-12-31")
y_x_df_raw.head()
# Out:
# [*********************100%%**********************]  2 of 2 completed
#             Adj Close                   Close                    High  \
#                  AAPL        ^GSPC       AAPL        ^GSPC       AAPL
# Date
# 2020-01-02  73.152649  3257.850098  75.087502  3257.850098  75.150002
# 2020-01-03  72.441452  3234.850098  74.357498  3234.850098  75.144997
# 2020-01-06  73.018692  3246.280029  74.949997  3246.280029  74.989998
# 2020-01-07  72.675278  3237.179932  74.597504  3237.179932  75.224998
# 2020-01-08  73.844353  3253.050049  75.797501  3253.050049  76.110001
#
#                                Low                    Open               \
#                   ^GSPC       AAPL        ^GSPC       AAPL        ^GSPC
# Date
# 2020-01-02  3258.139893  73.797501  3235.530029  74.059998  3244.669922
# 2020-01-03  3246.149902  74.125000  3222.340088  74.287498  3226.360107
# 2020-01-06  3246.840088  73.187500  3214.639893  73.447502  3217.550049
# 2020-01-07  3244.909912  74.370003  3232.429932  74.959999  3241.860107
# 2020-01-08  3267.070068  74.290001  3236.669922  74.290001  3238.590088
#
#                Volume
#                  AAPL       ^GSPC
# Date
# 2020-01-02  135480400  3459930000
# 2020-01-03  146322800  3484700000
# 2020-01-06  118387200  3702460000
# 2020-01-07  108872000  3435910000
# 2020-01-08  132079200  3726840000

# %%
y_x_df_raw.to_csv('y_x_df_raw.csv')
y_x_df_raw.to_pickle('y_x_df_raw.pkl')

# %%
# 收盘价，计算日回报率
y_x_df = y_x_df_raw['Adj Close'].pct_change()
y_x_df.dropna(inplace=True)

# %%
y_x_df.rename(columns={"^GSPC": "SP500"}, inplace=True)

# %%
y_x_df.head()
# Out:
#                 AAPL     SP500
# Date
# 2020-01-03 -0.009722 -0.007060
# 2020-01-06  0.007968  0.003533
# 2020-01-07 -0.004703 -0.002803
# 2020-01-08  0.016086  0.004902
# 2020-01-09  0.021241  0.006655

# %%
x_df = y_x_df[['SP500']]
y_df = y_x_df[['AAPL']]

# %%
#%% Data analysis

sns.jointplot(data=y_x_df, x="SP500", y="AAPL", kind="scatter", xlim=[-0.15, 0.15], ylim=[-0.15, 0.15])

# %%
# marginal and joint KDE plots
sns.jointplot(data=y_x_df, x="SP500", y="AAPL", kind="kde", cmap="Blues", fill=True, xlim=[-0.15, 0.15], ylim=[-0.15, 0.15])

# %%
SIGMA = y_x_df.cov()

fig, axs = plt.subplots()

h = sns.heatmap(SIGMA, annot=True, cmap="RdBu_r")
h.set_aspect("equal")
print(np.sqrt(np.diag(SIGMA)))
# Out:
# [0.02946919 0.02176789]

# %%
RHO = y_x_df.corr()

fig, axs = plt.subplots()

h = sns.heatmap(RHO, annot=True, cmap="RdBu_r")
h.set_aspect("equal")

# %%
Angles = np.arccos(RHO)*180/np.pi

fig, axs = plt.subplots()

h = sns.heatmap(Angles, annot=True, cmap="RdBu_r")
h.set_aspect("equal")

# %%
def draw_vector(vector, RBG):
    array = np.array([[0, 0, vector[0], vector[1]]])
    X, Y, U, V = zip(*array)
    plt.quiver(X, Y, U, V, angles='xy', scale_units='xy', scale=1, color=RBG)
    
angle = Angles['AAPL']['SP500']*np.pi/180

vols = np.sqrt(np.diag(SIGMA))
v_1_x = vols[1]
v_1_y = 0

v_2_x = vols[0] * np.cos(angle)
v_2_y = vols[0] * np.sin(angle)

# %%
fig, ax = plt.subplots()

draw_vector([v_1_x,v_1_y],np.array([0,112,192])/255)
draw_vector([v_2_x,v_2_y],np.array([255,0,0])/255)

plt.ylabel('$y, TSLA$')
plt.xlabel('$x, S&P500$')
plt.axis('scaled')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
ax.set_xlim([-0.01, 0.03])
ax.set_ylim([-0.01, 0.03])
ax.grid(linestyle='--', linewidth=0.25, color=[0.5,0.5,0.5])

# %%
X_df = sm.add_constant(x_df)

model = sm.OLS(y_df, X_df)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.687
# Method:                 Least Squares   F-statistic:                     550.5
# Date:                Thu, 28 Dec 2023   Prob (F-statistic):           5.16e-65
# Time:                        21:49:19   Log-Likelihood:                 675.37
# No. Observations:                 251   AIC:                            -1347.
# Df Residuals:                     249   BIC:                            -1340.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.001      1.819      0.070      -0.000       0.004
# SP500          1.1234      0.048     23.462      0.000       1.029       1.218
# ==============================================================================
# Omnibus:                       52.109   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.797
# Skew:                           0.772   Prob(JB):                     1.68e-46
# Kurtosis:                       7.216   Cond. No.                         46.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p = model.fit().params

# generate x-values for  regression line
x = np.linspace(x_df.min(),x_df.max(),10)

# %%
p
# Out:
# const    0.001893
# SP500    1.123351
# dtype: float64

# %%
fig, ax = plt.subplots()

# scatter-plot data
plt.scatter(x_df, y_df, alpha = 0.5)

plt.plot(x, p.const + p.SP500 * x, color = 'r')

plt.axhline(y=0, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
plt.axis('scaled')
plt.ylabel('AAPL daily log return')
plt.xlabel('S&P 500 daily log return, market')
plt.xlim([-0.15,0.15])
plt.ylim([-0.15,0.15])
# Out:
# (-0.15, 0.15)

# %%
sns.jointplot(x=x_df['SP500'], y=y_df['AAPL'], kind="reg",
              xlim = [-0.15,0.15],ylim = [-0.15,0.15])
